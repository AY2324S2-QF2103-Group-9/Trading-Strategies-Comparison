# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV 

pd.options.mode.chained_assignment = None
pd.set_option('display.max_columns', 100)

# %%
stocks = ['AAPL.O', 'MSFT.O', 'INTC.O', 'AMZN.O', 'GS.N']

# %% [markdown]
# ## Results of Grid Search for feature combination to use

# %%
test = pd.read_csv('feat_combi_grid_search.csv', 
                 index_col = 0)

display = 3

test.head(display)
# Out:
#            AAPL.O mean ret  MSFT.O mean ret  INTC.O mean ret  AMZN.O mean ret  \
# ma_feat          -0.170679        -0.202825        -0.068370        -0.111901
# sma_feat         -0.168306        -0.197447        -0.049525        -0.122131
# lag_feat         -0.150218        -0.195973        -0.038694        -0.119619
#
#            GS.N mean ret  AAPL.O ret  MSFT.O ret  INTC.O ret  AMZN.O ret  \
# ma_feat        -0.011510    0.442894    0.344107    0.276571    0.373906
# sma_feat       -0.033772    0.439312    0.333028    0.267139    0.366861
# lag_feat       -0.007856    0.449372    0.350056    0.278441    0.355496
#
#            GS.N ret  AAPL.O improvs  MSFT.O improvs  INTC.O improvs  \
# ma_feat    0.348518           355.0           268.0           397.0
# sma_feat   0.345053           339.0           245.0           406.0
# lag_feat   0.356509           360.0           276.0           431.0
#
#            AMZN.O improvs  GS.N improvs  AAPL.O falses  MSFT.O falses  \
# ma_feat             391.0         474.0     189.945055     193.845155
# sma_feat            352.0         444.0     189.982018     193.897103
# lag_feat            366.0         489.0     189.238761     193.824176
#
#            INTC.O falses  AMZN.O falses  GS.N falses  AAPL.O falses.1  \
# ma_feat       188.473526     182.861139   189.915085         9.696906
# sma_feat      188.546454     183.870130   190.674326         9.827191
# lag_feat      187.969031     182.588412   190.116883         9.369949
#
#            MSFT.O falses.1  INTC.O falses.1  AMZN.O falses.1  GS.N falses.1  \
# ma_feat           9.445899         9.772489         9.358082       9.533403
# sma_feat          9.386075         9.334136         9.123219       9.068508
# lag_feat          9.792602         9.640023         9.269759       9.407514
#
#            AAPL.O f1 mean  MSFT.O f1 mean  INTC.O f1 mean  AMZN.O f1 mean  \
# ma_feat          0.602919        0.613651        0.657886        0.682885
# sma_feat         0.603311        0.612766        0.657263        0.680080
# lag_feat         0.603717        0.612794        0.659115        0.683357
#
#            GS.N f1 mean  AAPL.O f1 std  MSFT.O f1 std  INTC.O f1 std  \
# ma_feat        0.632915       0.027451       0.026333       0.025970
# sma_feat       0.630474       0.027583       0.027212       0.024857
# lag_feat       0.631959       0.026655       0.027950       0.026010
#
#            AMZN.O f1 std  GS.N f1 std
# ma_feat         0.022633     0.025476
# sma_feat        0.022310     0.025309
# lag_feat        0.022429     0.025698

# %%
test.sort_values(by="AAPL.O mean ret", ascending=False).head(display)
# Out:
#                                      AAPL.O mean ret  MSFT.O mean ret  \
# sma_feat rsi_feat MACD_feat                -0.134836        -0.186420
# ma_feat sma_feat rsi_feat MACD_feat        -0.143572        -0.177468
# ma_feat lag_feat rsi_feat MACD_feat        -0.144023        -0.184562
#
#                                      INTC.O mean ret  AMZN.O mean ret  \
# sma_feat rsi_feat MACD_feat                -0.059804        -0.126810
# ma_feat sma_feat rsi_feat MACD_feat        -0.047011        -0.097269
# ma_feat lag_feat rsi_feat MACD_feat        -0.057971        -0.125222
#
#                                      GS.N mean ret  AAPL.O ret  MSFT.O ret  \
# sma_feat rsi_feat MACD_feat              -0.005446    0.434030    0.352633
# ma_feat sma_feat rsi_feat MACD_feat      -0.019488    0.450094    0.354759
# ma_feat lag_feat rsi_feat MACD_feat      -0.028648    0.446292    0.339867
#
#                                      INTC.O ret  AMZN.O ret  GS.N ret  \
# sma_feat rsi_feat MACD_feat            0.278474    0.358749  0.346723
# ma_feat sma_feat rsi_feat MACD_feat    0.283056    0.343030  0.340413
# ma_feat lag_feat rsi_feat MACD_feat    0.277760    0.357039  0.341228
#
#                                      AAPL.O improvs  MSFT.O improvs  \
# sma_feat rsi_feat MACD_feat                   370.0           271.0
# ma_feat sma_feat rsi_feat MACD_feat           364.0           274.0
# ma_feat lag_feat rsi_feat MACD_feat           350.0           267.0
#
#                                      INTC.O improvs  AMZN.O improvs  \
# sma_feat rsi_feat MACD_feat                   409.0           354.0
# ma_feat sma_feat rsi_feat MACD_feat           424.0           386.0
# ma_feat lag_feat rsi_feat MACD_feat           407.0           355.0
#
#                                      GS.N improvs  AAPL.O falses  \
# sma_feat rsi_feat MACD_feat                 483.0     189.077922
# ma_feat sma_feat rsi_feat MACD_feat         475.0     189.605395
# ma_feat lag_feat rsi_feat MACD_feat         463.0     189.217782
#
#                                      MSFT.O falses  INTC.O falses  \
# sma_feat rsi_feat MACD_feat             193.869131     188.506494
# ma_feat sma_feat rsi_feat MACD_feat     193.373626     188.024975
# ma_feat lag_feat rsi_feat MACD_feat     193.482517     188.381618
#
#                                      AMZN.O falses  GS.N falses  \
# sma_feat rsi_feat MACD_feat             183.620380   189.930070
# ma_feat sma_feat rsi_feat MACD_feat     183.341658   189.932068
# ma_feat lag_feat rsi_feat MACD_feat     183.025974   190.106893
#
#                                      AAPL.O falses.1  MSFT.O falses.1  \
# sma_feat rsi_feat MACD_feat                 9.417002         9.885740
# ma_feat sma_feat rsi_feat MACD_feat         9.532635         9.626747
# ma_feat lag_feat rsi_feat MACD_feat         9.386081         9.695047
#
#                                      INTC.O falses.1  AMZN.O falses.1  \
# sma_feat rsi_feat MACD_feat                 9.382761         9.123582
# ma_feat sma_feat rsi_feat MACD_feat         9.283985         9.457439
# ma_feat lag_feat rsi_feat MACD_feat         9.459293         9.067708
#
#                                      GS.N falses.1  AAPL.O f1 mean  \
# sma_feat rsi_feat MACD_feat               9.257057        0.604707
# ma_feat sma_feat rsi_feat MACD_feat       8.796555        0.604218
# ma_feat lag_feat rsi_feat MACD_feat       9.299009        0.604293
#
#                                      MSFT.O f1 mean  INTC.O f1 mean  \
# sma_feat rsi_feat MACD_feat                0.612859        0.657555
# ma_feat sma_feat rsi_feat MACD_feat        0.614607        0.659210
# ma_feat lag_feat rsi_feat MACD_feat        0.613234        0.657762
#
#                                      AMZN.O f1 mean  GS.N f1 mean  \
# sma_feat rsi_feat MACD_feat                0.680989      0.632212
# ma_feat sma_feat rsi_feat MACD_feat        0.681745      0.633597
# ma_feat lag_feat rsi_feat MACD_feat        0.682186      0.631799
#
#                                      AAPL.O f1 std  MSFT.O f1 std  \
# sma_feat rsi_feat MACD_feat               0.026671       0.028043
# ma_feat sma_feat rsi_feat MACD_feat       0.026817       0.027514
# ma_feat lag_feat rsi_feat MACD_feat       0.027082       0.028095
#
#                                      INTC.O f1 std  AMZN.O f1 std  GS.N f1 std
# sma_feat rsi_feat MACD_feat               0.025348       0.022267     0.025416
# ma_feat sma_feat rsi_feat MACD_feat       0.024737       0.022621     0.024555
# ma_feat lag_feat rsi_feat MACD_feat       0.025421       0.022413     0.026460

# %%
test.sort_values(by="AAPL.O improvs", ascending=False).head(display)
# Out:
#                                      AAPL.O mean ret  MSFT.O mean ret  \
# ma_feat lag_feat MACD_feat                 -0.152302        -0.189326
# sma_feat rsi_feat MACD_feat                -0.134836        -0.186420
# ma_feat sma_feat rsi_feat MACD_feat        -0.143572        -0.177468
#
#                                      INTC.O mean ret  AMZN.O mean ret  \
# ma_feat lag_feat MACD_feat                 -0.058820        -0.122886
# sma_feat rsi_feat MACD_feat                -0.059804        -0.126810
# ma_feat sma_feat rsi_feat MACD_feat        -0.047011        -0.097269
#
#                                      GS.N mean ret  AAPL.O ret  MSFT.O ret  \
# ma_feat lag_feat MACD_feat               -0.017641    0.446886    0.353421
# sma_feat rsi_feat MACD_feat              -0.005446    0.434030    0.352633
# ma_feat sma_feat rsi_feat MACD_feat      -0.019488    0.450094    0.354759
#
#                                      INTC.O ret  AMZN.O ret  GS.N ret  \
# ma_feat lag_feat MACD_feat             0.277709    0.344328  0.331937
# sma_feat rsi_feat MACD_feat            0.278474    0.358749  0.346723
# ma_feat sma_feat rsi_feat MACD_feat    0.283056    0.343030  0.340413
#
#                                      AAPL.O improvs  MSFT.O improvs  \
# ma_feat lag_feat MACD_feat                    376.0           287.0
# sma_feat rsi_feat MACD_feat                   370.0           271.0
# ma_feat sma_feat rsi_feat MACD_feat           364.0           274.0
#
#                                      INTC.O improvs  AMZN.O improvs  \
# ma_feat lag_feat MACD_feat                    400.0           354.0
# sma_feat rsi_feat MACD_feat                   409.0           354.0
# ma_feat sma_feat rsi_feat MACD_feat           424.0           386.0
#
#                                      GS.N improvs  AAPL.O falses  \
# ma_feat lag_feat MACD_feat                  452.0     189.497502
# sma_feat rsi_feat MACD_feat                 483.0     189.077922
# ma_feat sma_feat rsi_feat MACD_feat         475.0     189.605395
#
#                                      MSFT.O falses  INTC.O falses  \
# ma_feat lag_feat MACD_feat              193.531469     188.537463
# sma_feat rsi_feat MACD_feat             193.869131     188.506494
# ma_feat sma_feat rsi_feat MACD_feat     193.373626     188.024975
#
#                                      AMZN.O falses  GS.N falses  \
# ma_feat lag_feat MACD_feat              183.384615   190.118881
# sma_feat rsi_feat MACD_feat             183.620380   189.930070
# ma_feat sma_feat rsi_feat MACD_feat     183.341658   189.932068
#
#                                      AAPL.O falses.1  MSFT.O falses.1  \
# ma_feat lag_feat MACD_feat                  9.407138         9.514371
# sma_feat rsi_feat MACD_feat                 9.417002         9.885740
# ma_feat sma_feat rsi_feat MACD_feat         9.532635         9.626747
#
#                                      INTC.O falses.1  AMZN.O falses.1  \
# ma_feat lag_feat MACD_feat                  9.565189         8.919245
# sma_feat rsi_feat MACD_feat                 9.382761         9.123582
# ma_feat sma_feat rsi_feat MACD_feat         9.283985         9.457439
#
#                                      GS.N falses.1  AAPL.O f1 mean  \
# ma_feat lag_feat MACD_feat                9.348414        0.603845
# sma_feat rsi_feat MACD_feat               9.257057        0.604707
# ma_feat sma_feat rsi_feat MACD_feat       8.796555        0.604218
#
#                                      MSFT.O f1 mean  INTC.O f1 mean  \
# ma_feat lag_feat MACD_feat                 0.613098        0.657717
# sma_feat rsi_feat MACD_feat                0.612859        0.657555
# ma_feat sma_feat rsi_feat MACD_feat        0.614607        0.659210
#
#                                      AMZN.O f1 mean  GS.N f1 mean  \
# ma_feat lag_feat MACD_feat                 0.681226      0.631680
# sma_feat rsi_feat MACD_feat                0.680989      0.632212
# ma_feat sma_feat rsi_feat MACD_feat        0.681745      0.633597
#
#                                      AAPL.O f1 std  MSFT.O f1 std  \
# ma_feat lag_feat MACD_feat                0.027068       0.027068
# sma_feat rsi_feat MACD_feat               0.026671       0.028043
# ma_feat sma_feat rsi_feat MACD_feat       0.026817       0.027514
#
#                                      INTC.O f1 std  AMZN.O f1 std  GS.N f1 std
# ma_feat lag_feat MACD_feat                0.026482       0.021893     0.025690
# sma_feat rsi_feat MACD_feat               0.025348       0.022267     0.025416
# ma_feat sma_feat rsi_feat MACD_feat       0.024737       0.022621     0.024555

# %%
test.sort_values(by="MSFT.O mean ret", ascending=False).head(display)
# Out:
#                                      AAPL.O mean ret  MSFT.O mean ret  \
# ma_feat sma_feat rsi_feat MACD_feat        -0.143572        -0.177468
# ma_feat sma_feat lag_feat                  -0.163316        -0.178692
# ma_feat lag_feat rsi_feat                  -0.148692        -0.178750
#
#                                      INTC.O mean ret  AMZN.O mean ret  \
# ma_feat sma_feat rsi_feat MACD_feat        -0.047011        -0.097269
# ma_feat sma_feat lag_feat                  -0.057434        -0.121497
# ma_feat lag_feat rsi_feat                  -0.053706        -0.130404
#
#                                      GS.N mean ret  AAPL.O ret  MSFT.O ret  \
# ma_feat sma_feat rsi_feat MACD_feat      -0.019488    0.450094    0.354759
# ma_feat sma_feat lag_feat                -0.008055    0.437795    0.358274
# ma_feat lag_feat rsi_feat                -0.010591    0.451030    0.353280
#
#                                      INTC.O ret  AMZN.O ret  GS.N ret  \
# ma_feat sma_feat rsi_feat MACD_feat    0.283056    0.343030  0.340413
# ma_feat sma_feat lag_feat              0.265230    0.372698  0.339990
# ma_feat lag_feat rsi_feat              0.274839    0.397986  0.366477
#
#                                      AAPL.O improvs  MSFT.O improvs  \
# ma_feat sma_feat rsi_feat MACD_feat           364.0           274.0
# ma_feat sma_feat lag_feat                     339.0           276.0
# ma_feat lag_feat rsi_feat                     350.0           299.0
#
#                                      INTC.O improvs  AMZN.O improvs  \
# ma_feat sma_feat rsi_feat MACD_feat           424.0           386.0
# ma_feat sma_feat lag_feat                     416.0           375.0
# ma_feat lag_feat rsi_feat                     425.0           377.0
#
#                                      GS.N improvs  AAPL.O falses  \
# ma_feat sma_feat rsi_feat MACD_feat         475.0     189.605395
# ma_feat sma_feat lag_feat                   482.0     189.503497
# ma_feat lag_feat rsi_feat                   496.0     189.132867
#
#                                      MSFT.O falses  INTC.O falses  \
# ma_feat sma_feat rsi_feat MACD_feat     193.373626     188.024975
# ma_feat sma_feat lag_feat               193.686314     188.230769
# ma_feat lag_feat rsi_feat               193.630370     188.383616
#
#                                      AMZN.O falses  GS.N falses  \
# ma_feat sma_feat rsi_feat MACD_feat     183.341658   189.932068
# ma_feat sma_feat lag_feat               183.572428   189.858142
# ma_feat lag_feat rsi_feat               183.055944   190.151848
#
#                                      AAPL.O falses.1  MSFT.O falses.1  \
# ma_feat sma_feat rsi_feat MACD_feat         9.532635         9.626747
# ma_feat sma_feat lag_feat                   9.670173         9.620785
# ma_feat lag_feat rsi_feat                   9.501964         9.465899
#
#                                      INTC.O falses.1  AMZN.O falses.1  \
# ma_feat sma_feat rsi_feat MACD_feat         9.283985         9.457439
# ma_feat sma_feat lag_feat                   9.784257         8.785158
# ma_feat lag_feat rsi_feat                   9.298532         9.069888
#
#                                      GS.N falses.1  AAPL.O f1 mean  \
# ma_feat sma_feat rsi_feat MACD_feat       8.796555        0.604218
# ma_feat sma_feat lag_feat                 9.060125        0.604133
# ma_feat lag_feat rsi_feat                 9.575224        0.605198
#
#                                      MSFT.O f1 mean  INTC.O f1 mean  \
# ma_feat sma_feat rsi_feat MACD_feat        0.614607        0.659210
# ma_feat sma_feat lag_feat                  0.613340        0.658462
# ma_feat lag_feat rsi_feat                  0.613538        0.658046
#
#                                      AMZN.O f1 mean  GS.N f1 mean  \
# ma_feat sma_feat rsi_feat MACD_feat        0.681745      0.633597
# ma_feat sma_feat lag_feat                  0.681358      0.632908
# ma_feat lag_feat rsi_feat                  0.682186      0.632162
#
#                                      AAPL.O f1 std  MSFT.O f1 std  \
# ma_feat sma_feat rsi_feat MACD_feat       0.026817       0.027514
# ma_feat sma_feat lag_feat                 0.027582       0.027126
# ma_feat lag_feat rsi_feat                 0.027554       0.026198
#
#                                      INTC.O f1 std  AMZN.O f1 std  GS.N f1 std
# ma_feat sma_feat rsi_feat MACD_feat       0.024737       0.022621     0.024555
# ma_feat sma_feat lag_feat                 0.025454       0.021287     0.024603
# ma_feat lag_feat rsi_feat                 0.025086       0.021928     0.026051

# %%
test.sort_values(by="MSFT.O improvs", ascending=False).head(display)
# Out:
#                                       AAPL.O mean ret  MSFT.O mean ret  \
# sma_feat lag_feat rsi_feat MACD_feat        -0.173604        -0.183036
# sma_feat rsi_feat                           -0.174070        -0.181655
# ma_feat MACD_feat                           -0.158180        -0.191121
#
#                                       INTC.O mean ret  AMZN.O mean ret  \
# sma_feat lag_feat rsi_feat MACD_feat        -0.057310        -0.116713
# sma_feat rsi_feat                           -0.073536        -0.113033
# ma_feat MACD_feat                           -0.056794        -0.123951
#
#                                       GS.N mean ret  AAPL.O ret  MSFT.O ret  \
# sma_feat lag_feat rsi_feat MACD_feat      -0.037924    0.432810    0.364747
# sma_feat rsi_feat                         -0.012075    0.437992    0.354174
# ma_feat MACD_feat                         -0.026883    0.430836    0.363919
#
#                                       INTC.O ret  AMZN.O ret  GS.N ret  \
# sma_feat lag_feat rsi_feat MACD_feat    0.275782    0.370738  0.350767
# sma_feat rsi_feat                       0.275979    0.354087  0.355046
# ma_feat MACD_feat                       0.284657    0.370635  0.336514
#
#                                       AAPL.O improvs  MSFT.O improvs  \
# sma_feat lag_feat rsi_feat MACD_feat           331.0           303.0
# sma_feat rsi_feat                              349.0           302.0
# ma_feat MACD_feat                              342.0           302.0
#
#                                       INTC.O improvs  AMZN.O improvs  \
# sma_feat lag_feat rsi_feat MACD_feat           409.0           377.0
# sma_feat rsi_feat                              394.0           361.0
# ma_feat MACD_feat                              422.0           351.0
#
#                                       GS.N improvs  AAPL.O falses  \
# sma_feat lag_feat rsi_feat MACD_feat         455.0     189.902098
# sma_feat rsi_feat                            465.0     189.628372
# ma_feat MACD_feat                            446.0     190.000000
#
#                                       MSFT.O falses  INTC.O falses  \
# sma_feat lag_feat rsi_feat MACD_feat     193.701299     188.476523
# sma_feat rsi_feat                        193.256743     188.555445
# ma_feat MACD_feat                        193.776224     188.263736
#
#                                       AMZN.O falses  GS.N falses  \
# sma_feat lag_feat rsi_feat MACD_feat     182.805195   189.934066
# sma_feat rsi_feat                        182.390609   190.118881
# ma_feat MACD_feat                        183.214785   190.118881
#
#                                       AAPL.O falses.1  MSFT.O falses.1  \
# sma_feat lag_feat rsi_feat MACD_feat         9.368586         9.984472
# sma_feat rsi_feat                            9.458211         9.377367
# ma_feat MACD_feat                            9.576534         9.735496
#
#                                       INTC.O falses.1  AMZN.O falses.1  \
# sma_feat lag_feat rsi_feat MACD_feat         9.326612         9.201685
# sma_feat rsi_feat                            9.419723         9.062575
# ma_feat MACD_feat                            9.919696         9.012259
#
#                                       GS.N falses.1  AAPL.O f1 mean  \
# sma_feat lag_feat rsi_feat MACD_feat       9.435022        0.602769
# sma_feat rsi_feat                          9.334069        0.603255
# ma_feat MACD_feat                          9.124739        0.602230
#
#                                       MSFT.O f1 mean  INTC.O f1 mean  \
# sma_feat lag_feat rsi_feat MACD_feat        0.613795        0.658421
# sma_feat rsi_feat                           0.614534        0.658486
# ma_feat MACD_feat                           0.612681        0.657660
#
#                                       AMZN.O f1 mean  GS.N f1 mean  \
# sma_feat lag_feat rsi_feat MACD_feat        0.683048      0.632349
# sma_feat rsi_feat                           0.683807      0.632909
# ma_feat MACD_feat                           0.681416      0.631844
#
#                                       AAPL.O f1 std  MSFT.O f1 std  \
# sma_feat lag_feat rsi_feat MACD_feat       0.026932       0.028295
# sma_feat rsi_feat                          0.026996       0.026990
# ma_feat MACD_feat                          0.027277       0.028020
#
#                                       INTC.O f1 std  AMZN.O f1 std  \
# sma_feat lag_feat rsi_feat MACD_feat       0.025485       0.022108
# sma_feat rsi_feat                          0.025397       0.022324
# ma_feat MACD_feat                          0.027169       0.022237
#
#                                       GS.N f1 std
# sma_feat lag_feat rsi_feat MACD_feat     0.025841
# sma_feat rsi_feat                        0.025348
# ma_feat MACD_feat                        0.025472

# %%
test.sort_values(by="INTC.O mean ret", ascending=False).head(display)
# Out:
#                                      AAPL.O mean ret  MSFT.O mean ret  \
# lag_feat                                   -0.150218        -0.195973
# lag_feat rsi_feat                          -0.164015        -0.188781
# ma_feat sma_feat rsi_feat MACD_feat        -0.143572        -0.177468
#
#                                      INTC.O mean ret  AMZN.O mean ret  \
# lag_feat                                   -0.038694        -0.119619
# lag_feat rsi_feat                          -0.044095        -0.122951
# ma_feat sma_feat rsi_feat MACD_feat        -0.047011        -0.097269
#
#                                      GS.N mean ret  AAPL.O ret  MSFT.O ret  \
# lag_feat                                 -0.007856    0.449372    0.350056
# lag_feat rsi_feat                        -0.007561    0.434451    0.338638
# ma_feat sma_feat rsi_feat MACD_feat      -0.019488    0.450094    0.354759
#
#                                      INTC.O ret  AMZN.O ret  GS.N ret  \
# lag_feat                               0.278441    0.355496  0.356509
# lag_feat rsi_feat                      0.265184    0.375579  0.355513
# ma_feat sma_feat rsi_feat MACD_feat    0.283056    0.343030  0.340413
#
#                                      AAPL.O improvs  MSFT.O improvs  \
# lag_feat                                      360.0           276.0
# lag_feat rsi_feat                             339.0           256.0
# ma_feat sma_feat rsi_feat MACD_feat           364.0           274.0
#
#                                      INTC.O improvs  AMZN.O improvs  \
# lag_feat                                      431.0           366.0
# lag_feat rsi_feat                             420.0           368.0
# ma_feat sma_feat rsi_feat MACD_feat           424.0           386.0
#
#                                      GS.N improvs  AAPL.O falses  \
# lag_feat                                    489.0     189.238761
# lag_feat rsi_feat                           467.0     189.113886
# ma_feat sma_feat rsi_feat MACD_feat         475.0     189.605395
#
#                                      MSFT.O falses  INTC.O falses  \
# lag_feat                                193.824176     187.969031
# lag_feat rsi_feat                       193.534466     187.569431
# ma_feat sma_feat rsi_feat MACD_feat     193.373626     188.024975
#
#                                      AMZN.O falses  GS.N falses  \
# lag_feat                                182.588412   190.116883
# lag_feat rsi_feat                       182.831169   189.927073
# ma_feat sma_feat rsi_feat MACD_feat     183.341658   189.932068
#
#                                      AAPL.O falses.1  MSFT.O falses.1  \
# lag_feat                                    9.369949         9.792602
# lag_feat rsi_feat                           9.857840         9.387282
# ma_feat sma_feat rsi_feat MACD_feat         9.532635         9.626747
#
#                                      INTC.O falses.1  AMZN.O falses.1  \
# lag_feat                                    9.640023         9.269759
# lag_feat rsi_feat                           9.472351         9.407788
# ma_feat sma_feat rsi_feat MACD_feat         9.283985         9.457439
#
#                                      GS.N falses.1  AAPL.O f1 mean  \
# lag_feat                                  9.407514        0.603717
# lag_feat rsi_feat                         9.448581        0.604774
# ma_feat sma_feat rsi_feat MACD_feat       8.796555        0.604218
#
#                                      MSFT.O f1 mean  INTC.O f1 mean  \
# lag_feat                                   0.612794        0.659115
# lag_feat rsi_feat                          0.613679        0.659643
# ma_feat sma_feat rsi_feat MACD_feat        0.614607        0.659210
#
#                                      AMZN.O f1 mean  GS.N f1 mean  \
# lag_feat                                   0.683357      0.631959
# lag_feat rsi_feat                          0.682689      0.632707
# ma_feat sma_feat rsi_feat MACD_feat        0.681745      0.633597
#
#                                      AAPL.O f1 std  MSFT.O f1 std  \
# lag_feat                                  0.026655       0.027950
# lag_feat rsi_feat                         0.027952       0.026847
# ma_feat sma_feat rsi_feat MACD_feat       0.026817       0.027514
#
#                                      INTC.O f1 std  AMZN.O f1 std  GS.N f1 std
# lag_feat                                  0.026010       0.022429     0.025698
# lag_feat rsi_feat                         0.025804       0.022864     0.025479
# ma_feat sma_feat rsi_feat MACD_feat       0.024737       0.022621     0.024555

# %%
test.sort_values(by="INTC.O improvs", ascending=False).head(display)
# Out:
#                             AAPL.O mean ret  MSFT.O mean ret  INTC.O mean ret  \
# ma_feat lag_feat                  -0.151746        -0.195452        -0.053096
# lag_feat                          -0.150218        -0.195973        -0.038694
# ma_feat sma_feat MACD_feat        -0.163634        -0.195241        -0.053409
#
#                             AMZN.O mean ret  GS.N mean ret  AAPL.O ret  \
# ma_feat lag_feat                  -0.108168      -0.002116    0.437319
# lag_feat                          -0.119619      -0.007856    0.449372
# ma_feat sma_feat MACD_feat        -0.128161      -0.032779    0.428248
#
#                             MSFT.O ret  INTC.O ret  AMZN.O ret  GS.N ret  \
# ma_feat lag_feat              0.354862    0.277725    0.361442  0.353899
# lag_feat                      0.350056    0.278441    0.355496  0.356509
# ma_feat sma_feat MACD_feat    0.340292    0.282529    0.356896  0.353717
#
#                             AAPL.O improvs  MSFT.O improvs  INTC.O improvs  \
# ma_feat lag_feat                     348.0           282.0           444.0
# lag_feat                             360.0           276.0           431.0
# ma_feat sma_feat MACD_feat           347.0           270.0           428.0
#
#                             AMZN.O improvs  GS.N improvs  AAPL.O falses  \
# ma_feat lag_feat                     376.0         492.0     189.261738
# lag_feat                             366.0         489.0     189.238761
# ma_feat sma_feat MACD_feat           351.0         449.0     189.311688
#
#                             MSFT.O falses  INTC.O falses  AMZN.O falses  \
# ma_feat lag_feat               193.387612     187.555445     183.069930
# lag_feat                       193.824176     187.969031     182.588412
# ma_feat sma_feat MACD_feat     194.213786     187.692308     183.432567
#
#                             GS.N falses  AAPL.O falses.1  MSFT.O falses.1  \
# ma_feat lag_feat             189.763237         9.478155         9.339893
# lag_feat                     190.116883         9.369949         9.792602
# ma_feat sma_feat MACD_feat   190.510490         9.418639         9.473027
#
#                             INTC.O falses.1  AMZN.O falses.1  GS.N falses.1  \
# ma_feat lag_feat                   9.645474         8.987052       9.431272
# lag_feat                           9.640023         9.269759       9.407514
# ma_feat sma_feat MACD_feat         9.790262         9.122045       9.091872
#
#                             AAPL.O f1 mean  MSFT.O f1 mean  INTC.O f1 mean  \
# ma_feat lag_feat                  0.604341        0.614664        0.660310
# lag_feat                          0.603717        0.612794        0.659115
# ma_feat sma_feat MACD_feat        0.604064        0.611543        0.659500
#
#                             AMZN.O f1 mean  GS.N f1 mean  AAPL.O f1 std  \
# ma_feat lag_feat                  0.682449      0.633592       0.026704
# lag_feat                          0.683357      0.631959       0.026655
# ma_feat sma_feat MACD_feat        0.681101      0.631039       0.026155
#
#                             MSFT.O f1 std  INTC.O f1 std  AMZN.O f1 std  \
# ma_feat lag_feat                 0.027293        0.02589       0.021559
# lag_feat                         0.027950        0.02601       0.022429
# ma_feat sma_feat MACD_feat       0.026391        0.02622       0.022618
#
#                             GS.N f1 std
# ma_feat lag_feat               0.024885
# lag_feat                       0.025698
# ma_feat sma_feat MACD_feat     0.024943

# %%
test.sort_values(by="AMZN.O mean ret", ascending=False).head(display)
# Out:
#                                      AAPL.O mean ret  MSFT.O mean ret  \
# ma_feat sma_feat rsi_feat MACD_feat        -0.143572        -0.177468
# ma_feat rsi_feat                           -0.175243        -0.203941
# ma_feat lag_feat                           -0.151746        -0.195452
#
#                                      INTC.O mean ret  AMZN.O mean ret  \
# ma_feat sma_feat rsi_feat MACD_feat        -0.047011        -0.097269
# ma_feat rsi_feat                           -0.058394        -0.099312
# ma_feat lag_feat                           -0.053096        -0.108168
#
#                                      GS.N mean ret  AAPL.O ret  MSFT.O ret  \
# ma_feat sma_feat rsi_feat MACD_feat      -0.019488    0.450094    0.354759
# ma_feat rsi_feat                         -0.033053    0.434908    0.344406
# ma_feat lag_feat                         -0.002116    0.437319    0.354862
#
#                                      INTC.O ret  AMZN.O ret  GS.N ret  \
# ma_feat sma_feat rsi_feat MACD_feat    0.283056    0.343030  0.340413
# ma_feat rsi_feat                       0.277466    0.354482  0.331335
# ma_feat lag_feat                       0.277725    0.361442  0.353899
#
#                                      AAPL.O improvs  MSFT.O improvs  \
# ma_feat sma_feat rsi_feat MACD_feat           364.0           274.0
# ma_feat rsi_feat                              330.0           269.0
# ma_feat lag_feat                              348.0           282.0
#
#                                      INTC.O improvs  AMZN.O improvs  \
# ma_feat sma_feat rsi_feat MACD_feat           424.0           386.0
# ma_feat rsi_feat                              415.0           388.0
# ma_feat lag_feat                              444.0           376.0
#
#                                      GS.N improvs  AAPL.O falses  \
# ma_feat sma_feat rsi_feat MACD_feat         475.0     189.605395
# ma_feat rsi_feat                            442.0     189.375624
# ma_feat lag_feat                            492.0     189.261738
#
#                                      MSFT.O falses  INTC.O falses  \
# ma_feat sma_feat rsi_feat MACD_feat     193.373626     188.024975
# ma_feat rsi_feat                        194.101898     188.269730
# ma_feat lag_feat                        193.387612     187.555445
#
#                                      AMZN.O falses  GS.N falses  \
# ma_feat sma_feat rsi_feat MACD_feat     183.341658   189.932068
# ma_feat rsi_feat                        183.350649   190.133866
# ma_feat lag_feat                        183.069930   189.763237
#
#                                      AAPL.O falses.1  MSFT.O falses.1  \
# ma_feat sma_feat rsi_feat MACD_feat         9.532635         9.626747
# ma_feat rsi_feat                            9.677746         9.862637
# ma_feat lag_feat                            9.478155         9.339893
#
#                                      INTC.O falses.1  AMZN.O falses.1  \
# ma_feat sma_feat rsi_feat MACD_feat         9.283985         9.457439
# ma_feat rsi_feat                            9.443367         9.028838
# ma_feat lag_feat                            9.645474         8.987052
#
#                                      GS.N falses.1  AAPL.O f1 mean  \
# ma_feat sma_feat rsi_feat MACD_feat       8.796555        0.604218
# ma_feat rsi_feat                          9.379982        0.604769
# ma_feat lag_feat                          9.431272        0.604341
#
#                                      MSFT.O f1 mean  INTC.O f1 mean  \
# ma_feat sma_feat rsi_feat MACD_feat        0.614607        0.659210
# ma_feat rsi_feat                           0.612889        0.657977
# ma_feat lag_feat                           0.614664        0.660310
#
#                                      AMZN.O f1 mean  GS.N f1 mean  \
# ma_feat sma_feat rsi_feat MACD_feat        0.681745      0.633597
# ma_feat rsi_feat                           0.681477      0.631747
# ma_feat lag_feat                           0.682449      0.633592
#
#                                      AAPL.O f1 std  MSFT.O f1 std  \
# ma_feat sma_feat rsi_feat MACD_feat       0.026817       0.027514
# ma_feat rsi_feat                          0.027441       0.027790
# ma_feat lag_feat                          0.026704       0.027293
#
#                                      INTC.O f1 std  AMZN.O f1 std  GS.N f1 std
# ma_feat sma_feat rsi_feat MACD_feat       0.024737       0.022621     0.024555
# ma_feat rsi_feat                          0.025759       0.022236     0.025920
# ma_feat lag_feat                          0.025890       0.021559     0.024885

# %%
test.sort_values(by="AMZN.O improvs", ascending=False).head(display)
# Out:
#                                               AAPL.O mean ret  \
# ma_feat                                             -0.170679
# ma_feat sma_feat lag_feat rsi_feat MACD_feat        -0.175233
# ma_feat rsi_feat                                    -0.175243
#
#                                               MSFT.O mean ret  \
# ma_feat                                             -0.202825
# ma_feat sma_feat lag_feat rsi_feat MACD_feat        -0.190579
# ma_feat rsi_feat                                    -0.203941
#
#                                               INTC.O mean ret  \
# ma_feat                                             -0.068370
# ma_feat sma_feat lag_feat rsi_feat MACD_feat        -0.052515
# ma_feat rsi_feat                                    -0.058394
#
#                                               AMZN.O mean ret  GS.N mean ret  \
# ma_feat                                             -0.111901      -0.011510
# ma_feat sma_feat lag_feat rsi_feat MACD_feat        -0.123694      -0.042763
# ma_feat rsi_feat                                    -0.099312      -0.033053
#
#                                               AAPL.O ret  MSFT.O ret  \
# ma_feat                                         0.442894    0.344107
# ma_feat sma_feat lag_feat rsi_feat MACD_feat    0.445286    0.347794
# ma_feat rsi_feat                                0.434908    0.344406
#
#                                               INTC.O ret  AMZN.O ret  \
# ma_feat                                         0.276571    0.373906
# ma_feat sma_feat lag_feat rsi_feat MACD_feat    0.276718    0.382841
# ma_feat rsi_feat                                0.277466    0.354482
#
#                                               GS.N ret  AAPL.O improvs  \
# ma_feat                                       0.348518           355.0
# ma_feat sma_feat lag_feat rsi_feat MACD_feat  0.344588           333.0
# ma_feat rsi_feat                              0.331335           330.0
#
#                                               MSFT.O improvs  INTC.O improvs  \
# ma_feat                                                268.0           397.0
# ma_feat sma_feat lag_feat rsi_feat MACD_feat           273.0           403.0
# ma_feat rsi_feat                                       269.0           415.0
#
#                                               AMZN.O improvs  GS.N improvs  \
# ma_feat                                                391.0         474.0
# ma_feat sma_feat lag_feat rsi_feat MACD_feat           389.0         433.0
# ma_feat rsi_feat                                       388.0         442.0
#
#                                               AAPL.O falses  MSFT.O falses  \
# ma_feat                                          189.945055     193.845155
# ma_feat sma_feat lag_feat rsi_feat MACD_feat     189.552448     193.777223
# ma_feat rsi_feat                                 189.375624     194.101898
#
#                                               INTC.O falses  AMZN.O falses  \
# ma_feat                                          188.473526     182.861139
# ma_feat sma_feat lag_feat rsi_feat MACD_feat     188.251748     183.156843
# ma_feat rsi_feat                                 188.269730     183.350649
#
#                                               GS.N falses  AAPL.O falses.1  \
# ma_feat                                        189.915085         9.696906
# ma_feat sma_feat lag_feat rsi_feat MACD_feat   190.015984         9.489757
# ma_feat rsi_feat                               190.133866         9.677746
#
#                                               MSFT.O falses.1  \
# ma_feat                                              9.445899
# ma_feat sma_feat lag_feat rsi_feat MACD_feat         9.558416
# ma_feat rsi_feat                                     9.862637
#
#                                               INTC.O falses.1  \
# ma_feat                                              9.772489
# ma_feat sma_feat lag_feat rsi_feat MACD_feat         9.384698
# ma_feat rsi_feat                                     9.443367
#
#                                               AMZN.O falses.1  GS.N falses.1  \
# ma_feat                                              9.358082       9.533403
# ma_feat sma_feat lag_feat rsi_feat MACD_feat         8.876282       9.206831
# ma_feat rsi_feat                                     9.028838       9.379982
#
#                                               AAPL.O f1 mean  MSFT.O f1 mean  \
# ma_feat                                             0.602919        0.613651
# ma_feat sma_feat lag_feat rsi_feat MACD_feat        0.604201        0.613157
# ma_feat rsi_feat                                    0.604769        0.612889
#
#                                               INTC.O f1 mean  AMZN.O f1 mean  \
# ma_feat                                             0.657886        0.682885
# ma_feat sma_feat lag_feat rsi_feat MACD_feat        0.658276        0.681988
# ma_feat rsi_feat                                    0.657977        0.681477
#
#                                               GS.N f1 mean  AAPL.O f1 std  \
# ma_feat                                           0.632915       0.027451
# ma_feat sma_feat lag_feat rsi_feat MACD_feat      0.632415       0.026988
# ma_feat rsi_feat                                  0.631747       0.027441
#
#                                               MSFT.O f1 std  INTC.O f1 std  \
# ma_feat                                            0.026333       0.025970
# ma_feat sma_feat lag_feat rsi_feat MACD_feat       0.027405       0.025131
# ma_feat rsi_feat                                   0.027790       0.025759
#
#                                               AMZN.O f1 std  GS.N f1 std
# ma_feat                                            0.022633     0.025476
# ma_feat sma_feat lag_feat rsi_feat MACD_feat       0.021740     0.025634
# ma_feat rsi_feat                                   0.022236     0.025920

# %%
test.sort_values(by="GS.N mean ret", ascending=False).head(display)
# Out:
#                              AAPL.O mean ret  MSFT.O mean ret  \
# ma_feat lag_feat                   -0.151746        -0.195452
# sma_feat rsi_feat MACD_feat        -0.134836        -0.186420
# lag_feat rsi_feat                  -0.164015        -0.188781
#
#                              INTC.O mean ret  AMZN.O mean ret  GS.N mean ret  \
# ma_feat lag_feat                   -0.053096        -0.108168      -0.002116
# sma_feat rsi_feat MACD_feat        -0.059804        -0.126810      -0.005446
# lag_feat rsi_feat                  -0.044095        -0.122951      -0.007561
#
#                              AAPL.O ret  MSFT.O ret  INTC.O ret  AMZN.O ret  \
# ma_feat lag_feat               0.437319    0.354862    0.277725    0.361442
# sma_feat rsi_feat MACD_feat    0.434030    0.352633    0.278474    0.358749
# lag_feat rsi_feat              0.434451    0.338638    0.265184    0.375579
#
#                              GS.N ret  AAPL.O improvs  MSFT.O improvs  \
# ma_feat lag_feat             0.353899           348.0           282.0
# sma_feat rsi_feat MACD_feat  0.346723           370.0           271.0
# lag_feat rsi_feat            0.355513           339.0           256.0
#
#                              INTC.O improvs  AMZN.O improvs  GS.N improvs  \
# ma_feat lag_feat                      444.0           376.0         492.0
# sma_feat rsi_feat MACD_feat           409.0           354.0         483.0
# lag_feat rsi_feat                     420.0           368.0         467.0
#
#                              AAPL.O falses  MSFT.O falses  INTC.O falses  \
# ma_feat lag_feat                189.261738     193.387612     187.555445
# sma_feat rsi_feat MACD_feat     189.077922     193.869131     188.506494
# lag_feat rsi_feat               189.113886     193.534466     187.569431
#
#                              AMZN.O falses  GS.N falses  AAPL.O falses.1  \
# ma_feat lag_feat                183.069930   189.763237         9.478155
# sma_feat rsi_feat MACD_feat     183.620380   189.930070         9.417002
# lag_feat rsi_feat               182.831169   189.927073         9.857840
#
#                              MSFT.O falses.1  INTC.O falses.1  \
# ma_feat lag_feat                    9.339893         9.645474
# sma_feat rsi_feat MACD_feat         9.885740         9.382761
# lag_feat rsi_feat                   9.387282         9.472351
#
#                              AMZN.O falses.1  GS.N falses.1  AAPL.O f1 mean  \
# ma_feat lag_feat                    8.987052       9.431272        0.604341
# sma_feat rsi_feat MACD_feat         9.123582       9.257057        0.604707
# lag_feat rsi_feat                   9.407788       9.448581        0.604774
#
#                              MSFT.O f1 mean  INTC.O f1 mean  AMZN.O f1 mean  \
# ma_feat lag_feat                   0.614664        0.660310        0.682449
# sma_feat rsi_feat MACD_feat        0.612859        0.657555        0.680989
# lag_feat rsi_feat                  0.613679        0.659643        0.682689
#
#                              GS.N f1 mean  AAPL.O f1 std  MSFT.O f1 std  \
# ma_feat lag_feat                 0.633592       0.026704       0.027293
# sma_feat rsi_feat MACD_feat      0.632212       0.026671       0.028043
# lag_feat rsi_feat                0.632707       0.027952       0.026847
#
#                              INTC.O f1 std  AMZN.O f1 std  GS.N f1 std
# ma_feat lag_feat                  0.025890       0.021559     0.024885
# sma_feat rsi_feat MACD_feat       0.025348       0.022267     0.025416
# lag_feat rsi_feat                 0.025804       0.022864     0.025479

# %%
test.sort_values(by="GS.N improvs", ascending=False).head(display)
# Out:
#                             AAPL.O mean ret  MSFT.O mean ret  INTC.O mean ret  \
# ma_feat lag_feat rsi_feat         -0.148692        -0.178750        -0.053706
# ma_feat lag_feat                  -0.151746        -0.195452        -0.053096
# lag_feat                          -0.150218        -0.195973        -0.038694
#
#                             AMZN.O mean ret  GS.N mean ret  AAPL.O ret  \
# ma_feat lag_feat rsi_feat         -0.130404      -0.010591    0.451030
# ma_feat lag_feat                  -0.108168      -0.002116    0.437319
# lag_feat                          -0.119619      -0.007856    0.449372
#
#                             MSFT.O ret  INTC.O ret  AMZN.O ret  GS.N ret  \
# ma_feat lag_feat rsi_feat     0.353280    0.274839    0.397986  0.366477
# ma_feat lag_feat              0.354862    0.277725    0.361442  0.353899
# lag_feat                      0.350056    0.278441    0.355496  0.356509
#
#                             AAPL.O improvs  MSFT.O improvs  INTC.O improvs  \
# ma_feat lag_feat rsi_feat            350.0           299.0           425.0
# ma_feat lag_feat                     348.0           282.0           444.0
# lag_feat                             360.0           276.0           431.0
#
#                             AMZN.O improvs  GS.N improvs  AAPL.O falses  \
# ma_feat lag_feat rsi_feat            377.0         496.0     189.132867
# ma_feat lag_feat                     376.0         492.0     189.261738
# lag_feat                             366.0         489.0     189.238761
#
#                             MSFT.O falses  INTC.O falses  AMZN.O falses  \
# ma_feat lag_feat rsi_feat      193.630370     188.383616     183.055944
# ma_feat lag_feat               193.387612     187.555445     183.069930
# lag_feat                       193.824176     187.969031     182.588412
#
#                             GS.N falses  AAPL.O falses.1  MSFT.O falses.1  \
# ma_feat lag_feat rsi_feat    190.151848         9.501964         9.465899
# ma_feat lag_feat             189.763237         9.478155         9.339893
# lag_feat                     190.116883         9.369949         9.792602
#
#                             INTC.O falses.1  AMZN.O falses.1  GS.N falses.1  \
# ma_feat lag_feat rsi_feat          9.298532         9.069888       9.575224
# ma_feat lag_feat                   9.645474         8.987052       9.431272
# lag_feat                           9.640023         9.269759       9.407514
#
#                             AAPL.O f1 mean  MSFT.O f1 mean  INTC.O f1 mean  \
# ma_feat lag_feat rsi_feat         0.605198        0.613538        0.658046
# ma_feat lag_feat                  0.604341        0.614664        0.660310
# lag_feat                          0.603717        0.612794        0.659115
#
#                             AMZN.O f1 mean  GS.N f1 mean  AAPL.O f1 std  \
# ma_feat lag_feat rsi_feat         0.682186      0.632162       0.027554
# ma_feat lag_feat                  0.682449      0.633592       0.026704
# lag_feat                          0.683357      0.631959       0.026655
#
#                             MSFT.O f1 std  INTC.O f1 std  AMZN.O f1 std  \
# ma_feat lag_feat rsi_feat        0.026198       0.025086       0.021928
# ma_feat lag_feat                 0.027293       0.025890       0.021559
# lag_feat                         0.027950       0.026010       0.022429
#
#                             GS.N f1 std
# ma_feat lag_feat rsi_feat      0.026051
# ma_feat lag_feat               0.024885
# lag_feat                       0.025698

# %%
heads = 10
lst = list(test.sort_values(by=f"AAPL.O improvs", ascending=False).head(heads).index)

for stock in stocks:
    # lst2 = list(test.sort_values(by=f"{stock} mean ret", ascending=False).head(heads).index)
    lst1 = list(test.sort_values(by=f"{stock} improvs", ascending=False).head(heads).index)
    lst = list(set(lst) & set(lst1))
    # lst = list(set(lst) & set(lst2))

lst
# Out:
# ['ma_feat lag_feat rsi_feat ']
